# %% [markdown]
# # Assignment 1 ExamPreparatinOnline
#
# data source is http://bit.ly/epo_automation_csv_file

# %%
import pandas as pd    # importing pandas

# %%
data=pd.read_csv("Automatic email content store.csv",'$')     # bringing the csv file into ipynotebook

# %%
data                    # first look at data
# Out:
#                          Date                              to   \
# 0                    30/09/17       shubhi.prakash03@gmail.com
# 1                    30/09/17  exampreparationonline@gmail.com
# 2                    30/09/17  exampreparationonline@gmail.com
# 3                    30/09/17       shubhi.prakash03@gmail.com
# 4                    30/09/17       shubhi.prakash03@gmail.com
# 5                    30/09/17  exampreparationonline@gmail.com
# 6                    30/09/17       shubhi.prakash03@gmail.com
# 7                    30/09/17           nidhisaini05@gmail.com
# 8                    30/09/17    chowdhuryshaif@rediffmail.com
# 9                    30/09/17    chowdhuryshaif@rediffmail.com
# 10                   30/09/17    chowdhuryshaif@rediffmail.com
# 11                   30/09/17    chowdhuryshaif@rediffmail.com
# 12                   30/09/17    chowdhuryshaif@rediffmail.com
# 13                   30/09/17    chowdhuryshaif@rediffmail.com
# ...

# %%
data.isnull().sum()    # checking for null values
# Out:
# Date    0
# to      0
# raw     0
# dtype: int64

# %%
data.describe()               # summarising the data
# Out:
#             Date                            to                          raw
# count         46                             46                          46
# unique         6                             11                           4
# top     30/09/17  chowdhuryshaif@rediffmail.com  can u tell me the details?
# freq          15                             17                          22

# %%
data.columns.values.tolist()        # getting column names
# Out:
# ['Date', 'to ', 'raw']

# %%
len(data['to '].unique())
# Out:
# 11

# %%
mailAddress=data['to '].unique()

# %%
mailAddress                           # generating unique mail addresses
# Out:
# array(['shubhi.prakash03@gmail.com', 'exampreparationonline@gmail.com',
#        'nidhisaini05@gmail.com', 'chowdhuryshaif@rediffmail.com',
#        'abhishekguragol@gmail.com', 'sonuyannam@gmail.com',
#        'sachinsn231@gmail.com', 'limithakeerthi@gmail.com',
#        'ramthakkar07@gmail.com', 'pavithramurugan22@gmail.com',
#        'saha.swapankumar1@gmail.com'], dtype=object)

# %%
reference=data.groupby('to ').last()

# %%
lastDateOfConversation=reference['Date']                # getting the last date of conversation for each user

# %%
reference
# Out:
#                                      Date                            raw
# to
# abhishekguragol@gmail.com        01/10/17     can u tell me the details?
# chowdhuryshaif@rediffmail.com    02/10/17          when is the deadline?
# exampreparationonline@gmail.com  03/10/17          when is the deadline?
# limithakeerthi@gmail.com         03/10/17          when is the deadline?
# nidhisaini05@gmail.com           02/10/17     can u tell me the details?
# pavithramurugan22@gmail.com      03/10/17          when is the deadline?
# ramthakkar07@gmail.com           03/10/17          when is the deadline?
# sachinsn231@gmail.com            03/10/17          when is the deadline?
# saha.swapankumar1@gmail.com      04/10/17          when is the deadline?
# shubhi.prakash03@gmail.com       30/09/17  try to submit it with details
# sonuyannam@gmail.com             01/10/17     can u tell me the details?

# %%
lastDateOfConversation
# Out:
# to
# abhishekguragol@gmail.com          01/10/17
# chowdhuryshaif@rediffmail.com      02/10/17
# exampreparationonline@gmail.com    03/10/17
# limithakeerthi@gmail.com           03/10/17
# nidhisaini05@gmail.com             02/10/17
# pavithramurugan22@gmail.com        03/10/17
# ramthakkar07@gmail.com             03/10/17
# sachinsn231@gmail.com              03/10/17
# saha.swapankumar1@gmail.com        04/10/17
# shubhi.prakash03@gmail.com         30/09/17
# sonuyannam@gmail.com               01/10/17
# Name: Date, dtype: object

# %%
helperArray=["OpenCV","Python"]                  # creating the array to check for keywords

# %%
def generateColumnHelper (str):
    for i in helperArray:
        if(i in str):
            return i
        else:
            continue
    return ""

# %%
data['Keyword']=data.raw.apply(generateColumnHelper)             # inserting a value in new column if keyword is present

# %%
data
# Out:
#                          Date                              to   \
# 0                    30/09/17       shubhi.prakash03@gmail.com
# 1                    30/09/17  exampreparationonline@gmail.com
# 2                    30/09/17  exampreparationonline@gmail.com
# 3                    30/09/17       shubhi.prakash03@gmail.com
# 4                    30/09/17       shubhi.prakash03@gmail.com
# 5                    30/09/17  exampreparationonline@gmail.com
# 6                    30/09/17       shubhi.prakash03@gmail.com
# 7                    30/09/17           nidhisaini05@gmail.com
# 8                    30/09/17    chowdhuryshaif@rediffmail.com
# 9                    30/09/17    chowdhuryshaif@rediffmail.com
# 10                   30/09/17    chowdhuryshaif@rediffmail.com
# 11                   30/09/17    chowdhuryshaif@rediffmail.com
# 12                   30/09/17    chowdhuryshaif@rediffmail.com
# 13                   30/09/17    chowdhuryshaif@rediffmail.com
# ...

# %%
data.to_csv('assignment1.csv')
